# %%
from src.data.preprocessing import bandpass, highpass
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2025-05-20 19:26:16.285 | INFO     | bachelors_thesis.config:<module>:11 - PROJ_ROOT path is: C:\Users\natem\bachelors_thesis

# %%
# Load the ECG data
signals = np.load('../../data/processed/ptbxl100all/train.npy')
signals.shape
# Out:
# (17418, 1000, 12)

# %%
idx = 0
# View a signal before bandpass filtering
sig = signals[idx, :, 0]
plt.plot(sig)

# %%
bandpass_sig = bandpass(sig, sampling_rate=100, order=4, low=0.5, high=40)
plt.plot(bandpass_sig)

# %%
# highpass
highpass_sig = highpass(sig, sampling_rate=100, order=4, low=0.5)
plt.plot(highpass_sig)

# %%
# Compare original, bandpass, and highpass signals
plt.figure(figsize=(12, 8))
plt.subplot(3, 1, 1)
plt.plot(sig)
plt.title('Original Signal')
plt.subplot(3, 1, 2)
plt.plot(bandpass_sig)
plt.title('Bandpass Filtered Signal')
plt.subplot(3, 1, 3)
plt.plot(highpass_sig)
plt.title('Highpass Filtered Signal')
plt.tight_layout()
plt.show()

# %%
# %timeit bandpass(sig, 100, order=4, low=0.5, high=40)
# Out:
# 265 μs ± 9.61 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit highpass(sig, 100, order=4, low=0.5)
# Out:
# 201 μs ± 9.02 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
